# %%
from pandas import DataFrame

Cars = {'Brand': ['Honda Civic','Toyota Corolla','Ford Focus','Audi A4'],
        'Price': [22000,25000,27000,35000],
        "owner" : ["21201", "21202", "21203", "21202"]
        }

cars_df = DataFrame(Cars,columns= ['Brand', 'Price', "owner"])
cars_df
# Out:
#             Brand  Price  owner
# 0     Honda Civic  22000  21201
# 1  Toyota Corolla  25000  21202
# 2      Ford Focus  27000  21203
# 3         Audi A4  35000  21202

# %%
data = {
        "id" : ["21201", "21202", "21203", "21202"],
        'Name':['Tom', 'Jack', 'Steve', 'Ricky'],
        'Age':[28,34,29,42]
        }
person_df = DataFrame(data)
person_df
# Out:
#    Age   Name     id
# 0   28    Tom  21201
# 1   34   Jack  21202
# 2   29  Steve  21203
# 3   42  Ricky  21202

# %%
import pandas as pd
merge_df = pd.merge(cars_df, person_df, left_on="owner", right_on="id", how="outer")
merge_df
# Out:
#             Brand  Price  owner  Age   Name     id
# 0     Honda Civic  22000  21201   28    Tom  21201
# 1  Toyota Corolla  25000  21202   34   Jack  21202
# 2  Toyota Corolla  25000  21202   42  Ricky  21202
# 3         Audi A4  35000  21202   34   Jack  21202
# 4         Audi A4  35000  21202   42  Ricky  21202
# 5      Ford Focus  27000  21203   29  Steve  21203

# %%
import pandasql as ps
q1 = """SELECT * FROM merge_df WHERE Price < 25000"""
print(ps.sqldf(q1, locals()))
# Out:
#          Brand  Price  owner  Age Name     id
# 0  Honda Civic  22000  21201   28  Tom  21201

# %%
merge_df[merge_df["Price"] < 25000]
# Out:
#          Brand  Price  owner  Age Name     id
# 0  Honda Civic  22000  21201   28  Tom  21201

# %%
import pandas as pd

airports = pd.read_csv('data/airports.csv')
airport_freq = pd.read_csv('data/airport-frequencies.csv')
runways = pd.read_csv('data/runways.csv')

# %%
# select * from airports                       
airports
# Out:
#            id    ident            type  \
# 0        6523      00A        heliport
# 1      323361     00AA   small_airport
# 2        6524     00AK   small_airport
# 3        6525     00AL   small_airport
# 4        6526     00AR          closed
# 5      322127     00AS   small_airport
# 6        6527     00AZ   small_airport
# 7        6528     00CA   small_airport
# 8      324424     00CL   small_airport
# 9      322658     00CN        heliport
# 10       6529     00CO          closed
# 11       6531     00FA   small_airport
# 12       6532     00FD        heliport
# 13       6533     00FL   small_airport
# 14       6534     00GA   small_airport
# 15       6535     00GE        heliport
# 16       6536     00HI        heliport
# 17       6537     00ID   small_airport
# 18     322581     00IG   small_airport
# 19       6538     00II        heliport
# 20       6539     00IL   small_airport
# 21       6540     00IN        heliport
# 22       6541     00IS   small_airport
# 23       6542     00KS   small_airport
# 24       6543     00KY   small_airport
# 25      45437     00LA        heliport
# 26       6544     00LL        heliport
# 27       6545     00LS   small_airport
# 28       6546     00MD   small_airport
# 29       6547     00MI        heliport
# ...       ...      ...             ...
# 55255   30646     ZYAS  medium_airport
# 55256   27237     ZYCC  medium_airport
# 55257  300858     ZYCH  medium_airport
# 55258   30827     ZYCY  medium_airport
# 55259  327349     ZYDU  medium_airport
# 55260  324338     ZYFX   small_airport
# 55261  313994     ZYFY  medium_airport
# 55262   27238     ZYHB   large_airport
# 55263   31576     ZYHE  medium_airport
# 55264   31701     ZYJL   small_airport
# 55265   27239     ZYJM  medium_airport
# 55266  327450     ZYJS  medium_airport
# 55267  313337     ZYJX  medium_airport
# 55268   31706     ZYJZ  medium_airport
# 55269  307012     ZYLD  medium_airport
# 55270  300516     ZYLS  medium_airport
# 55271   27240     ZYMD  medium_airport
# 55272  301193     ZYMH  medium_airport
# 55273   27241     ZYQQ  medium_airport
# 55274  327451     ZYSQ  medium_airport
# 55275  307017     ZYTH   small_airport
# 55276   27242     ZYTL   large_airport
# 55277  307013     ZYTN  medium_airport
# 55278   27243     ZYTX   large_airport
# 55279   27244     ZYYJ  medium_airport
# 55280  317861     ZYYK  medium_airport
# 55281   32753     ZYYY  medium_airport
# 55282   46378  ZZ-0001        heliport
# 55283  307326  ZZ-0002   small_airport
# 55284  313629     ZZZZ   small_airport
#
#                                            name  latitude_deg  longitude_deg  \
# 0                             Total Rf Heliport     40.070801     -74.933601
# 1                          Aero B Ranch Airport     38.704022    -101.473911
# 2                                  Lowell Field     59.949200    -151.695999
# 3                                  Epps Airpark     34.864799     -86.770302
# 4            Newport Hospital & Clinic Heliport     35.608700     -91.254898
# 5                                Fulton Airport     34.942803     -97.818019
# 6                                Cordes Airport     34.305599    -112.165001
# 7                       Goldstone /Gts/ Airport     35.350498    -116.888000
# 8                           Williams Ag Airport     39.427188    -121.763427
# 9               Kitchen Creek Helibase Heliport     32.727374    -116.459742
# 10                                   Cass Field     40.622202    -104.344002
# 11                          Grass Patch Airport     28.645500     -82.219002
# 12                           Ringhaver Heliport     28.846600     -82.345398
# 13                            River Oak Airport     27.230900     -80.969200
# 14                             Lt World Airport     33.767502     -84.068298
# 15                             Caffrey Heliport     33.884201     -84.733902
# 16                           Kaupulehu Heliport     19.832715    -155.980233
# 17                         Delta Shores Airport     48.145302    -116.213997
# 18                                Goltl Airport     39.724028    -101.395994
# 19           Bailey Generation Station Heliport     41.644501     -87.122803
# 20                               Hammer Airport     41.978401     -89.560402
# 21              St Mary Medical Center Heliport     41.511398     -87.260597
# 22            Hayenga's Cant Find Farms Airport     40.025600     -89.122902
# 23                          Hayden Farm Airport     38.727798     -94.930496
# 24                        Robbins Roost Airport     37.409401     -84.619698
# 25            Shell Chemical East Site Heliport     30.191944     -90.980833
# 26                   Ac & R Components Heliport     39.665298     -89.705597
# 27                              Lejeune Airport     30.136299     -92.429398
# 28                                 Slater Field     38.757099     -75.753799
# 29                        Dow Chemical Heliport     43.949402     -86.416702
# ...                                         ...           ...            ...
# 55255                           Anshan Air Base     41.105301     122.853996
# 55256                           Longjia Airport     43.996201     125.684998
# 55257                          Changhai Airport     39.266667     122.666944
# 55258                          Chaoyang Airport     41.538101     120.434998
# 55259                  Wudalianchi Dedu Airport     48.445000     126.133000
# 55260                             Fuxin Airport     42.069014     121.718122
# 55261                             Dongji Aiport     48.199494     134.366447
# 55262                           Taiping Airport     45.623402     126.250000
# 55263                             Heihe Airport     50.171621     127.308884
# 55264                             Jilin Airport     44.002201     126.396004
# 55265                           Jiamusi Airport     46.843399     130.464996
# 55266                      Jiansanjiang Airport     47.110000     132.660278
# 55267                    Jixi Xingkaihu Airport     45.293000     131.193000
# 55268                           Jinzhou Airport     41.101398     121.061996
# 55269                             Lindu Airport     47.752056     129.019125
# 55270                      Yushu Batang Airport     32.836389      97.036389
# 55271  Mudanjiang Hailang International Airport     44.524101     129.569000
# 55272                           Gu-Lian Airport     52.912778     122.430000
# 55273                  Qiqihar Sanjiazi Airport     47.239601     123.917999
# 55274                 Songyuan Chaganhu Airport     44.938114     124.550178
# 55275                              Tahe Airport     52.224444     124.720222
# 55276                        Zhoushuizi Airport     38.965698     121.539001
# 55277                 Tonghua Sanyuanpu Airport     42.253889     125.703333
# 55278                           Taoxian Airport     41.639801     123.483002
# 55279               Yanji Chaoyangchuan Airport     42.882801     129.451004
# 55280                     Yingkou Lanqi Airport     40.542524     122.358600
# 55281                   Shenyang Dongta Airport     41.784401     123.496002
# 55282                           Sealand Helipad     51.894444       1.482500
# 55283                 Glorioso Islands Airstrip    -11.584278      47.296389
# 55284                    Satsuma Iōjima Airport     30.784722     130.270556
#
#        elevation_ft continent iso_country iso_region  \
# 0              11.0       NaN          US      US-PA
# 1            3435.0       NaN          US      US-KS
# 2             450.0       NaN          US      US-AK
# 3             820.0       NaN          US      US-AL
# 4             237.0       NaN          US      US-AR
# 5            1100.0       NaN          US      US-OK
# 6            3810.0       NaN          US      US-AZ
# 7            3038.0       NaN          US      US-CA
# 8              87.0       NaN          US      US-CA
# 9            3350.0       NaN          US      US-CA
# 10           4830.0       NaN          US      US-CO
# 11             53.0       NaN          US      US-FL
# 12             25.0       NaN          US      US-FL
# 13             35.0       NaN          US      US-FL
# 14            700.0       NaN          US      US-GA
# 15            957.0       NaN          US      US-GA
# 16             43.0       NaN          US      US-HI
# 17           2064.0       NaN          US      US-ID
# 18           3359.0       NaN          US      US-KS
# 19            600.0       NaN          US      US-IN
# 20            840.0       NaN          US      US-IL
# 21            634.0       NaN          US      US-IN
# 22            820.0       NaN          US      US-IL
# 23           1100.0       NaN          US      US-KS
# 24           1265.0       NaN          US      US-KY
# 25             15.0       NaN          US      US-LA
# 26            600.0       NaN          US      US-IL
# 27             12.0       NaN          US      US-LA
# 28             45.0       NaN          US      US-MD
# 29            588.0       NaN          US      US-MI
# ...             ...       ...         ...        ...
# 55255           NaN        AS          CN      CN-21
# 55256         706.0        AS          CN      CN-22
# 55257          80.0        AS          CN      CN-21
# 55258         568.0        AS          CN      CN-21
# 55259         984.0        AS          CN      CN-23
# 55260         548.0        AS          CN      CN-21
# 55261           NaN        AS          CN      CN-23
# 55262         457.0        AS          CN      CN-23
# 55263        8530.0        AS          CN      CN-23
# 55264           NaN        AS          CN      CN-22
# 55265         262.0        AS          CN      CN-23
# 55266           NaN        AS          CN      CN-23
# 55267         760.0        AS          CN      CN-23
# 55268           NaN        AS          CN      CN-21
# 55269         791.0        AS          CN      CN-23
# 55270       12816.0        AS          CN      CN-63
# 55271         883.0        AS          CN      CN-23
# 55272        1836.0        AS          CN      CN-23
# 55273         477.0        AS          CN      CN-23
# 55274         459.0        AS          CN      CN-22
# 55275        1240.0        AS          CN      CN-23
# 55276         107.0        AS          CN      CN-21
# 55277        1200.0        AS          CN      CN-22
# 55278         198.0        AS          CN      CN-21
# 55279         624.0        AS          CN      CN-22
# 55280           0.0        AS          CN      CN-21
# 55281           NaN        AS          CN      CN-21
# 55282          40.0        EU          GB     GB-ENG
# 55283          11.0        AF          TF     TF-U-A
# 55284         338.0        AS          JP      JP-46
#
#                                municipality scheduled_service gps_code  \
# 0                                  Bensalem                no      00A
# 1                                     Leoti                no     00AA
# 2                              Anchor Point                no     00AK
# 3                                   Harvest                no     00AL
# 4                                   Newport                no      NaN
# 5                                      Alex                no     00AS
# 6                                    Cordes                no     00AZ
# 7                                   Barstow                no     00CA
# 8                                     Biggs                no     00CL
# 9                               Pine Valley                no     00CN
# 10                               Briggsdale                no      NaN
# 11                                 Bushnell                no     00FA
# 12                                Riverview                no     00FD
# 13                               Okeechobee                no     00FL
# 14                                 Lithonia                no     00GA
# 15                                    Hiram                no     00GE
# 16                              Kailua/Kona                no     00HI
# 17                               Clark Fork                no     00ID
# 18                                 McDonald                no     00IG
# 19                               Chesterton                no     00II
# 20                                     Polo                no     00IL
# 21                                   Hobart                no     00IN
# 22                                    Kings                no     00IS
# 23                                  Gardner                no     00KS
# 24                                 Stanford                no     00KY
# 25                                 Gonzales                no     00LA
# 26                                  Chatham                no     00LL
# 27                                Esterwood                no     00LS
# 28                             Federalsburg                no     00MD
# 29                                Ludington                no     00MI
# ...                                     ...               ...      ...
# 55255                                Anshan               yes     ZYAS
# 55256                             Changchun               yes     ZYCC
# 55257                              Changhai                no     ZYCH
# 55258                              Chaoyang               yes     ZYCY
# 55259                           Wudalianchi               yes     ZYDU
# 55260                                 Fuxin                no     ZYFX
# 55261                                Fuyuan               yes     ZYFY
# 55262                                Harbin               yes     ZYHB
# 55263                                 Heihe               yes     ZYHE
# 55264                                 Jilin                no     ZYJL
# 55265                               Jiamusi               yes     ZYJM
# 55266                          Jiansanjiang               yes     ZYJS
# 55267                                  Jixi               yes     ZYJX
# 55268                               Jinzhou               yes     ZYJZ
# 55269                                Yichun               yes     ZYLD
# 55270                                 Yushu                no     ZYLS
# 55271                            Mudanjiang               yes     ZYMD
# 55272                                  Mohe               yes     ZYMH
# 55273                               Qiqihar               yes     ZYQQ
# 55274  Qian Gorlos Mongol Autonomous County               yes     ZYSQ
# 55275                                  Tahe                no     ZYTH
# 55276                                Dalian               yes     ZYTL
# 55277                               Tonghua               yes     ZYTN
# 55278                              Shenyang               yes     ZYTX
# 55279                                 Yanji               yes     ZYYJ
# 55280                               Yingkou               yes     ZYYK
# 55281                              Shenyang                no     ZYYY
# 55282                               Sealand                no      NaN
# 55283                      Grande Glorieuse                no      NaN
# 55284                          Mishima-Mura                no     RJX7
#
#       iata_code local_code                   home_link  \
# 0           NaN        00A                         NaN
# 1           NaN       00AA                         NaN
# 2           NaN       00AK                         NaN
# 3           NaN       00AL                         NaN
# 4           NaN        NaN                         NaN
# 5           NaN       00AS                         NaN
# 6           NaN       00AZ                         NaN
# 7           NaN       00CA                         NaN
# 8           NaN       00CL                         NaN
# 9           NaN       00CN                         NaN
# 10          NaN        NaN                         NaN
# 11          NaN       00FA                         NaN
# 12          NaN       00FD                         NaN
# 13          NaN       00FL                         NaN
# 14          NaN       00GA                         NaN
# 15          NaN       00GE                         NaN
# 16          NaN       00HI                         NaN
# 17          NaN       00ID                         NaN
# 18          NaN       00IG                         NaN
# 19          NaN       00II                         NaN
# 20          NaN       00IL                         NaN
# 21          NaN       00IN                         NaN
# 22          NaN       00IS                         NaN
# 23          NaN       00KS                         NaN
# 24          NaN       00KY                         NaN
# 25          NaN       00LA                         NaN
# 26          NaN       00LL                         NaN
# 27          NaN       00LS                         NaN
# 28          NaN       00MD                         NaN
# 29          NaN       00MI                         NaN
# ...         ...        ...                         ...
# 55255       AOG        NaN                         NaN
# 55256       CGQ        NaN                         NaN
# 55257       CNI        NaN                         NaN
# 55258       CHG        NaN                         NaN
# 55259       DTU        NaN                         NaN
# 55260       NaN        NaN                         NaN
# 55261       FYJ        NaN                         NaN
# 55262       HRB        NaN                         NaN
# 55263       HEK        NaN                         NaN
# 55264       JIL        NaN                         NaN
# 55265       JMU        NaN                         NaN
# 55266       JSJ        NaN                         NaN
# 55267       JXA        NaN                         NaN
# 55268       JNZ        NaN                         NaN
# 55269       LDS        NaN                         NaN
# 55270       YUS        NaN                         NaN
# 55271       MDG        NaN                         NaN
# 55272       OHE        NaN                         NaN
# 55273       NDG        NaN                         NaN
# 55274       YSQ        NaN                         NaN
# 55275       NaN        NaN                         NaN
# 55276       DLC        NaN                         NaN
# 55277       TNH        NaN                         NaN
# 55278       SHE        NaN                         NaN
# 55279       YNJ        NaN                         NaN
# 55280       YKH        NaN                         NaN
# 55281       NaN        NaN                         NaN
# 55282       NaN        NaN  http://www.sealandgov.org/
# 55283       NaN        NaN                         NaN
# 55284       NaN        NaN                         NaN
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 9                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 19                                                   NaN
# 20                                                   NaN
# 21                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 29                                                   NaN
# ...                                                  ...
# 55255  https://en.wikipedia.org/wiki/Anshan_Teng%27ao...
# 55256  http://en.wikipedia.org/wiki/Changchun_Longjia...
# 55257      http://en.wikipedia.org/wiki/Changhai_Airport
# 55258     https://en.wikipedia.org/wiki/Chaoyang_Airport
# 55259  https://en.wikipedia.org/wiki/Wudalianchi_Dedu...
# 55260                                                NaN
# 55261  https://en.wikipedia.org/wiki/Fuyuan_Dongji_Ai...
# 55262  http://en.wikipedia.org/wiki/Harbin_Taiping_In...
# 55263         http://en.wikipedia.org/wiki/Heihe_Airport
# 55264  https://en.wikipedia.org/wiki/Jilin_Ertaizi_Ai...
# 55265       http://en.wikipedia.org/wiki/Jiamusi_Airport
# 55266  https://en.wikipedia.org/wiki/Jiansanjiang_Air...
# 55267  http://en.wikipedia.org/wiki/Jixi_Xingkaihu_Ai...
# 55268       http://en.wikipedia.org/wiki/Jinzhou_Airport
# 55269  http://en.wikipedia.org/wiki/Yichun_Lindu_Airport
# 55270  http://en.wikipedia.org/wiki/Yushu_Batang_Airport
# 55271    http://en.wikipedia.org/wiki/Mudanjiang_Airport
# 55272   http://en.wikipedia.org/wiki/Mohe_Gulian_Airport
# 55273       http://en.wikipedia.org/wiki/Qiqihar_Airport
# 55274  https://en.wikipedia.org/wiki/Songyuan_Chaganh...
# 55275                                                NaN
# 55276  http://en.wikipedia.org/wiki/Dalian_Zhoushuizi...
# 55277  http://en.wikipedia.org/wiki/Tonghua_Sanyuanpu...
# 55278  http://en.wikipedia.org/wiki/Shenyang_Taoxian_...
# 55279  http://en.wikipedia.org/wiki/Yanji_Chaoyangchu...
# 55280  https://en.wikipedia.org/wiki/Yingkou_Lanqi_Ai...
# 55281                                                NaN
# 55282  http://en.wikipedia.org/wiki/Principality_of_S...
# 55283                                                NaN
# 55284  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                     keywords
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                       00AR
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9                        NaN
# 10                      00CO
# 11                       NaN
# 12                       NaN
# 13                       NaN
# 14                       NaN
# 15                       NaN
# 16                       NaN
# 17                       NaN
# 18                       NaN
# 19                       NaN
# 20                       NaN
# 21                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 25                       NaN
# 26                       NaN
# 27                       NaN
# 28                       NaN
# 29                       NaN
# ...                      ...
# 55255                    NaN
# 55256                    NaN
# 55257                    NaN
# 55258                    NaN
# 55259                    NaN
# 55260                    NaN
# 55261                    NaN
# 55262                    NaN
# 55263                    NaN
# 55264                    NaN
# 55265                    NaN
# 55266                    NaN
# 55267                    NaN
# 55268    Xiaolingzi Air Base
# 55269     Yichun Shi Airport
# 55270                    NaN
# 55271             Mudanjiang
# 55272                    NaN
# 55273                    NaN
# 55274                    NaN
# 55275                    NaN
# 55276        Dalian Air Base
# 55277  Tonghua Liuhe Airport
# 55278                    NaN
# 55279                    NaN
# 55280                    NaN
# 55281                    NaN
# 55282   Roughs Tower Helipad
# 55283                    NaN
# 55284   SATSUMA,IWOJIMA,RJX7
#
# [55285 rows x 18 columns]

# %%
# select * from airports limit 3               
airports.head(3)
# Out:
#        id ident           type                  name  latitude_deg  \
# 0    6523   00A       heliport     Total Rf Heliport     40.070801
# 1  323361  00AA  small_airport  Aero B Ranch Airport     38.704022
# 2    6524  00AK  small_airport          Lowell Field     59.949200
#
#    longitude_deg  elevation_ft continent iso_country iso_region  municipality  \
# 0     -74.933601          11.0       NaN          US      US-PA      Bensalem
# 1    -101.473911        3435.0       NaN          US      US-KS         Leoti
# 2    -151.695999         450.0       NaN          US      US-AK  Anchor Point
#
#   scheduled_service gps_code iata_code local_code home_link wikipedia_link  \
# 0                no      00A       NaN        00A       NaN            NaN
# 1                no     00AA       NaN       00AA       NaN            NaN
# 2                no     00AK       NaN       00AK       NaN            NaN
#
#   keywords
# 0      NaN
# 1      NaN
# 2      NaN

# %%
# select id from airports where ident = 'KLAX' 
airports[airports.ident == 'KLAX'].id
# Out:
# 27881    3632
# Name: id, dtype: int64

# %%
# select distinct type from airport            
airports.type.unique()
# Out:
# array(['heliport', 'small_airport', 'closed', 'seaplane_base',
#        'balloonport', 'medium_airport', 'large_airport'], dtype=object)

# %%
# select * from airports where iso_region = 'US-CA' and type = 'seaplane_base'                         
airports[(airports.iso_region == 'US-CA') & (airports.type == 'seaplane_base')]
# Out:
#            id ident           type                                      name  \
# 979      7436   0O0  seaplane_base          San Luis Reservoir Seaplane Base
# 2497     8877  22CA  seaplane_base            Commodore Center Seaplane Base
# 6247    12298  5CA9  seaplane_base       Konocti  - Clear Lake Seaplane Base
# 12956   16514   C39  seaplane_base                 Folsom Lake Seaplane Base
# 15283   16830  CN20  seaplane_base             Ferndale Resort Seaplane Base
# 17666   17157   E20  seaplane_base              Lake Berryessa Seaplane Base
# 22854   17613   H77  seaplane_base           Bridge Bay Resort Seaplane Base
# 30620   21444   L11  seaplane_base                Pebbly Beach Seaplane Base
# 37193   23479   O06  seaplane_base  Lake Oroville Landing Area Seaplane Base
# 40883   24384   S74  seaplane_base                   Lost Isle Seaplane Base
# 48316  300312   TWH  seaplane_base           Two Harbors Amphibious Terminal
#
#        latitude_deg  longitude_deg  elevation_ft continent iso_country  \
# 979       37.058300    -121.125999         544.0       NaN          US
# 2497      37.879902    -122.514000           NaN       NaN          US
# 6247      38.977699    -122.718002        1326.0       NaN          US
# 12956     38.707199    -121.133003         466.0       NaN          US
# 15283     39.002998    -122.796997        1326.0       NaN          US
# 17666     38.591599    -122.259003         440.0       NaN          US
# 22854     40.757599    -122.322998        1065.0       NaN          US
# 30620     33.338402    -118.311996           NaN       NaN          US
# 37193     39.566601    -121.468002         900.0       NaN          US
# 40883     38.004101    -121.457001           NaN       NaN          US
# 48316     33.432222    -118.508611           NaN       NaN          US
#
#       iso_region municipality scheduled_service gps_code iata_code local_code  \
# 979        US-CA    Los Banos                no      0O0       NaN        0O0
# 2497       US-CA    Sausalito                no     22CA       NaN       22CA
# 6247       US-CA  Kelseyville                no     5CA9       NaN       5CA9
# 12956      US-CA       Folsom                no      C39       NaN        C39
# 15283      US-CA  Kelseyville                no     CN20       NaN       CN20
# 17666      US-CA         Napa                no      E20       NaN        E20
# 22854      US-CA      Redding                no      H77       NaN        H77
# 30620      US-CA       Avalon                no     KL11       NaN        L11
# 37193      US-CA     Oroville                no      O06       NaN        O06
# 40883      US-CA     Stockton                no      S74       NaN        S74
# 48316      US-CA  Two Harbors                no      NaN       TWH        NaN
#
#       home_link wikipedia_link keywords
# 979         NaN            NaN      NaN
# 2497        NaN            NaN      NaN
# 6247        NaN            NaN      NaN
# 12956       NaN            NaN      NaN
# 15283       NaN            NaN      NaN
# 17666       NaN            NaN      NaN
# 22854       NaN            NaN      NaN
# 30620       NaN            NaN      NaN
# 37193       NaN            NaN      NaN
# 40883       NaN            NaN      NaN
# 48316       NaN            NaN      NaN

# %%
# select ident, name, municipality from airports where iso_region = 'US-CA' and type = 'large_airport'
airports[(airports.iso_region == 'US-CA') & (airports.type == 'large_airport')][['ident', 'name', 'municipality']]
# Out:
#       ident                                             name   municipality
# 26251  KBAB                             Beale Air Force Base     Marysville
# 27091  KEDW                           Edwards Air Force Base        Edwards
# 27881  KLAX                Los Angeles International Airport    Los Angeles
# 28408  KOAK       Metropolitan Oakland International Airport        Oakland
# 28464  KONT                    Ontario International Airport        Ontario
# 29986  KSAN                  San Diego International Airport      San Diego
# 30026  KSFO              San Francisco International Airport  San Francisco
# 30047  KSJC  Norman Y. Mineta San Jose International Airport       San Jose
# 30069  KSMF                 Sacramento International Airport     Sacramento
# 30075  KSNA         John Wayne Airport-Orange County Airport      Santa Ana
# 30124  KSUU                            Travis Air Force Base      Fairfield
# 30357  KVBG                        Vandenberg Air Force Base         Lompoc

# %%
# select * from airport_freq where airport_ident = 'KLAX' order by type      
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type')
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11917  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11918  60766         3632          KLAX   APP   SOCAL APP         124.30
# 11919  60768         3632          KLAX  ATIS        ATIS         133.80
# 11920  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11921  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11922  60771         3632          KLAX   GND         GND         121.65
# 11923  60772         3632          KLAX  MISC          CG          34.50
# 11924  60773         3632          KLAX  MISC          CG         898.40
# 11925  60774         3632          KLAX   OPS          AF          37.22
# 11926  60775         3632          KLAX   TWR         TWR         119.80
# 11927  60776         3632          KLAX  UNIC      UNICOM         122.95

# %%
# select * from airport_freq where airport_ident = 'KLAX' order by type desc
airport_freq[airport_freq.airport_ident == 'KLAX'].sort_values('type', ascending=False)
# Out:
#           id  airport_ref airport_ident  type description  frequency_mhz
# 11927  60776         3632          KLAX  UNIC      UNICOM         122.95
# 11926  60775         3632          KLAX   TWR         TWR         119.80
# 11925  60774         3632          KLAX   OPS          AF          37.22
# 11923  60772         3632          KLAX  MISC          CG          34.50
# 11924  60773         3632          KLAX  MISC          CG         898.40
# 11922  60771         3632          KLAX   GND         GND         121.65
# 11921  60770         3632          KLAX   DEP   SOCAL DEP         124.30
# 11920  60769         3632          KLAX   CLD    CLNC DEL         121.40
# 11919  60768         3632          KLAX  ATIS        ATIS         133.80
# 11917  60767         3632          KLAX   APP   SOCAL APP          36.07
# 11918  60766         3632          KLAX   APP   SOCAL APP         124.30

# %%
# select * from airports where type in ('heliport', 'balloonport')     
airports[airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident      type  \
# 0        6523      00A  heliport
# 9      322658     00CN  heliport
# 12       6532     00FD  heliport
# 15       6535     00GE  heliport
# 16       6536     00HI  heliport
# 19       6538     00II  heliport
# 21       6540     00IN  heliport
# 25      45437     00LA  heliport
# 26       6544     00LL  heliport
# 29       6547     00MI  heliport
# 35       6553     00NJ  heliport
# 39       6556     00OI  heliport
# 41       6557     00OR  heliport
# 42       6558     00PA  heliport
# 48       6562     00TA  heliport
# 49       6563     00TE  heliport
# 61     322300     00WY  heliport
# 64       6577     01AK  heliport
# 66       6579     01AR  heliport
# 67       6580     01AZ  heliport
# 69       6582     01CA  heliport
# 71       6584     01CN  heliport
# 72       6585     01CO  heliport
# 73       6586     01CT  heliport
# 75       6588     01FD  heliport
# 77       6590     01GA  heliport
# 82       6594     01IL  heliport
# 83       6595     01IN  heliport
# 88       6600     01KY  heliport
# 92       6604     01MA  heliport
# ...       ...      ...       ...
# 54691  309376     YXPM  heliport
# 54692  309316     YXPN  heliport
# 54693  309375     YXQU  heliport
# 54694  309374     YXRN  heliport
# 54695  309342     YXSA  heliport
# 54696  309353     YXSC  heliport
# 54697  309344     YXSG  heliport
# 54698  309352     YXSH  heliport
# 54699  309351     YXSI  heliport
# 54700  309343     YXSU  heliport
# 54702  310102     YXTE  heliport
# 54703  313356     YXTN  heliport
# 54704  310101     YXTR  heliport
# 54705  309333     YXTT  heliport
# 54706  309334     YXTW  heliport
# 54707  317136     YXUH  heliport
# 54708  310103     YXWG  heliport
# 54709  309327     YXWL  heliport
# 54710  311184     YXWT  heliport
# 54711  310104     YXWW  heliport
# 54712  309326     YXWY  heliport
# 54713  309325     YXYO  heliport
# 54722   28091     YYBK  heliport
# 54800   41544  ZA-0021  heliport
# 54896  312611  ZA-0117  heliport
# 54898  312624  ZA-0119  heliport
# 54919  318475  ZA-0140  heliport
# 54946  331062  ZA-0167  heliport
# 55021  301278      ZIZ  heliport
# 55282   46378  ZZ-0001  heliport
#
#                                                    name  latitude_deg  \
# 0                                     Total Rf Heliport     40.070801
# 9                       Kitchen Creek Helibase Heliport     32.727374
# 12                                   Ringhaver Heliport     28.846600
# 15                                     Caffrey Heliport     33.884201
# 16                                   Kaupulehu Heliport     19.832715
# 19                   Bailey Generation Station Heliport     41.644501
# 21                      St Mary Medical Center Heliport     41.511398
# 25                    Shell Chemical East Site Heliport     30.191944
# 26                           Ac & R Components Heliport     39.665298
# 29                                Dow Chemical Heliport     43.949402
# 35                          Colgate-Piscataway Heliport     40.520901
# 39                       Miami Valley Hospital Heliport     39.745300
# 41                               Steel Systems Heliport     44.932899
# 42                                       R J D Heliport     39.948898
# 48                               Sw Region Faa Heliport     32.826900
# 49                       Tcjc-Northeast Campus Heliport     32.847599
# 61             Mountain View Regional Hospital Heliport     42.840361
# 64            Providence Seward Medical Center Heliport     60.105874
# 66              Community Hospital of De Queen Heliport     34.047298
# 67                                         Yat Heliport     34.608101
# 69                             Lugo Substation Heliport     34.368241
# 71     Los Angeles County Sheriff's Department Heliport     34.037800
# 72                 St Vincent General Hospital Heliport     39.245300
# 73                          Berlin Fairgrounds Heliport     41.627300
# 75             Advent Health Altamonte Springs Heliport     28.666639
# 77                              Medical Center Heliport     32.479301
# 82       Hoopeston Community Memorial Hospital Heliport     40.458599
# 83                          Community Hospital Heliport     40.130901
# 88                            Lourdes Hospital Heliport     37.051701
# 92                              Compaq Andover Heliport     42.625099
# ...                                                 ...           ...
# 54691                   Port Macquarie Hospital Helipad    -31.452683
# 54692                       Proserpine Hospital Helipad    -20.399120
# 54693                         Quirindi Hospital Helipad    -31.501070
# 54694                         Rylstone Hospital Helipad    -32.803975
# 54695                 Sydney Adventist Hospital Helipad    -33.733386
# 54696                            Scone Hospital Helipad    -32.050268
# 54697                        St George Hospital Helipad    -33.968070
# 54698                     Shellharbour Hospital Helipad    -34.559890
# 54699                        Singleton Hospital Helipad    -32.567080
# 54700                       Sutherland Hospital Helipad    -34.038783
# 54702            Tenterfield - Federation Park Heliport    -29.048000
# 54703          Trundle Hospital Helicopter Landing Site    -32.921700
# 54704                      Taree - Wrigley Park Helipad    -31.906400
# 54705                            Tumut Hospital Helipad    -35.308000
# 54706                         Tamworth Hospital Helipad    -31.074570
# 54707                Bulahdelah Helicopter Landing Site    -32.400000
# 54708                 Wagga - Duke of Kent Oval Helipad    -35.114340
# 54709                       Wollongong Hospital Helipad    -34.424190
# 54710                   Wellington-Rygate Park Heliport    -32.548700
# 54711                          Wee Waa Hospital Helipad    -30.225000
# 54712                            Wyong Hospital Helipad    -33.260250
# 54713                            Young Hospital Helipad    -34.320940
# 54722                               Yarra Bank Heliport    -37.822287
# 54800                         Pretoria Central Heliport    -25.655701
# 54896                                     Pumba Helipad    -33.387799
# 54898                                Cape Town Heliport    -33.901018
# 54919                         Kuruman Hospital Heliport    -27.459904
# 54946                                       kemptonpark      0.000000
# 55021                                  Zamzama Heliport     26.710944
# 55282                                   Sealand Helipad     51.894444
#
#        longitude_deg  elevation_ft continent iso_country iso_region  \
# 0         -74.933601          11.0       NaN          US      US-PA
# 9        -116.459742        3350.0       NaN          US      US-CA
# 12        -82.345398          25.0       NaN          US      US-FL
# 15        -84.733902         957.0       NaN          US      US-GA
# 16       -155.980233          43.0       NaN          US      US-HI
# 19        -87.122803         600.0       NaN          US      US-IN
# 21        -87.260597         634.0       NaN          US      US-IN
# 25        -90.980833          15.0       NaN          US      US-LA
# 26        -89.705597         600.0       NaN          US      US-IL
# 29        -86.416702         588.0       NaN          US      US-MI
# 35        -74.474602          78.0       NaN          US      US-NJ
# 39        -84.187401         905.0       NaN          US      US-OH
# 41       -123.129997         195.0       NaN          US      US-OR
# 42        -75.746902         402.0       NaN          US      US-PA
# 48        -97.305801         598.0       NaN          US      US-TX
# 49        -97.189499         600.0       NaN          US      US-TX
# 61       -106.224443        5210.0       NaN          US      US-WY
# 64       -149.446249         120.0       NaN          US      US-AK
# 66        -94.354897         400.0       NaN          US      US-AR
# 67       -111.864998        3300.0       NaN          US      US-AZ
# 69       -117.370059        3733.0       NaN          US      US-CA
# 71       -118.153999         300.0       NaN          US      US-CA
# 72       -106.246002       10175.0       NaN          US      US-CO
# 73        -72.727501          60.0       NaN          US      US-CT
# 75        -81.369700          86.0       NaN          US      US-FL
# 77        -84.979103         319.0       NaN          US      US-GA
# 82        -87.659500         583.0       NaN          US      US-IL
# 83        -85.695801         890.0       NaN          US      US-IN
# 88        -88.646896         419.0       NaN          US      US-KY
# 92        -71.180099         140.0       NaN          US      US-MA
# ...              ...           ...       ...         ...        ...
# 54691     152.880760          32.0        OC          AU     AU-NSW
# 54692     148.585500          44.0        OC          AU     AU-QLD
# 54693     150.676606        1365.0        OC          AU     AU-NSW
# 54694     149.975076        1971.0        OC          AU     AU-NSW
# 54695     151.100006         584.0        OC          AU     AU-NSW
# 54696     150.877663         782.0        OC          AU     AU-NSW
# 54697     151.133680         150.0        OC          AU     AU-NSW
# 54698     150.841730          99.0        OC          AU     AU-NSW
# 54699     151.186865         151.0        OC          AU     AU-NSW
# 54700     151.115600         119.0        OC          AU     AU-NSW
# 54702     152.016400        2762.0        OC          AU     AU-NSW
# 54703     147.706700         822.0        OC          AU     AU-NSW
# 54704     152.450800          39.0        OC          AU     AU-NSW
# 54705     148.219100        1052.0        OC          AU     AU-NSW
# 54706     150.926410        1356.0        OC          AU     AU-NSW
# 54707     152.200000          13.0        OC          AU     AU-NSW
# 54708     147.354100         588.0        OC          AU     AU-NSW
# 54709     150.882200         160.0        OC          AU     AU-NSW
# 54710     148.949700        1005.0        OC          AU     AU-NSW
# 54711     149.448300         632.0        OC          AU     AU-NSW
# 54712     151.480690          94.0        OC          AU     AU-NSW
# 54713     148.287980        1523.0        OC          AU     AU-NSW
# 54722     144.956792           NaN        OC          AU     AU-VIC
# 54800      28.220600        4087.0        AF          ZA      ZA-GT
# 54896      26.410595           NaN        AF          ZA      ZA-EC
# 54898      18.425936           NaN        AF          ZA      ZA-WC
# 54919      23.443762           NaN        AF          ZA      ZA-NC
# 54946       0.000000           NaN        AF          ZA      ZA-GT
# 55021      67.667250         128.0        AS          PK      PK-SD
# 55282       1.482500          40.0        EU          GB     GB-ENG
#
#              municipality scheduled_service gps_code iata_code local_code  \
# 0                Bensalem                no      00A       NaN        00A
# 9             Pine Valley                no     00CN       NaN       00CN
# 12              Riverview                no     00FD       NaN       00FD
# 15                  Hiram                no     00GE       NaN       00GE
# 16            Kailua/Kona                no     00HI       NaN       00HI
# 19             Chesterton                no     00II       NaN       00II
# 21                 Hobart                no     00IN       NaN       00IN
# 25               Gonzales                no     00LA       NaN       00LA
# 26                Chatham                no     00LL       NaN       00LL
# 29              Ludington                no     00MI       NaN       00MI
# 35          New Brunswick                no     00NJ       NaN       00NJ
# 39                 Dayton                no     00OI       NaN       00OI
# 41                  Salem                no     00OR       NaN       00OR
# 42            Coatesville                no     00PA       NaN       00PA
# 48             Fort Worth                no     00TA       NaN       00TA
# 49             Fort Worth                no     00TE       NaN       00TE
# 61                 Casper                no     00WY       NaN       00WY
# 64                 Seward                no     01AK       NaN       01AK
# 66               De Queen                no     01AR       NaN       01AR
# 67             Camp Verde                no     01AZ       NaN       01AZ
# 69               Hesperia                no     01CA       NaN       01CA
# 71            Los Angeles                no     01CN       NaN       01CN
# 72              Leadville                no     01CO       NaN       01CO
# 73                 Berlin                no     01CT       NaN       01CT
# 75      Altamonte Springs                no     01FD       NaN       01FD
# 77               Columbus                no     01GA       NaN       01GA
# 82              Hoopeston                no     01IL       NaN       01IL
# 83               Anderson                no     01IN       NaN       01IN
# 88                Paducah                no     01KY       NaN       01KY
# 92                Andover                no     01MA       NaN       01MA
# ...                   ...               ...      ...       ...        ...
# 54691      Port Macquarie                no     YXPM       NaN       YXPM
# 54692          Proserpine                no     YXPN       NaN       YXPN
# 54693            Quirindi                no     YXQU       NaN       YXQU
# 54694            Rylstone                no     YXRN       NaN       YXRN
# 54695           Wahroonga                no     YXSA       NaN       YXSA
# 54696               Scone                no     YXSC       NaN       YXSC
# 54697             Kogarah                no     YXSG       NaN       YXSG
# 54698        Shellharbour                no     YXSH       NaN       YXSH
# 54699           Singleton                no     YXSI       NaN       YXSI
# 54700             Miranda                no     YXSU       NaN       YXSU
# 54702         Tenterfield                no     YXTE       NaN       YXTE
# 54703             Trundle                no     YXTN       NaN       YXTN
# 54704               Taree                no     YXTR       NaN       YXTR
# 54705               Tumut                no     YXTT       NaN       YXTT
# 54706            Tamworth                no     YXTW       NaN       YXTW
# 54707          Bulahdelah                no     YXUH       NaN       YXUH
# 54708               Wagga                no     YXWG       NaN       YXWG
# 54709          Wollongong                no     YXWL       NaN       YXWL
# 54710          Wellington                no     YXWT       NaN       YXWT
# 54711             Wee Waa                no     YXWW       NaN       YXWW
# 54712               Wyong                no     YXWY       NaN       YXWY
# 54713               Young                no     YXYO       NaN       YXYO
# 54722                 NaN                no     YYBK       NaN        NaN
# 54800            Pretoria                no      NaN       HPR        NaN
# 54896  Nelson Mandela Bay                no      NaN       NaN        NaN
# 54898                 NaN                no      NaN       NaN        NaN
# 54919             Kuruman                no      NaN       NaN        NaN
# 54946             gauteng               yes      NaN       NaN        NaN
# 55021   Zamzama Gas Field                no      NaN       ZIZ        NaN
# 55282             Sealand                no      NaN       NaN        NaN
#
#                                          home_link  \
# 0                                              NaN
# 9                                              NaN
# 12                                             NaN
# 15                                             NaN
# 16                                             NaN
# 19                                             NaN
# 21                                             NaN
# 25                                             NaN
# 26                                             NaN
# 29                                             NaN
# 35                                             NaN
# 39                                             NaN
# 41                                             NaN
# 42                                             NaN
# 48                                             NaN
# 49                                             NaN
# 61                                             NaN
# 64                                             NaN
# 66                                             NaN
# 67                                             NaN
# 69                                             NaN
# 71                                             NaN
# 72                                             NaN
# 73                                             NaN
# 75                                             NaN
# 77                                             NaN
# 82                                             NaN
# 83                                             NaN
# 88                                             NaN
# 92                                             NaN
# ...                                            ...
# 54691                                          NaN
# 54692                                          NaN
# 54693                                          NaN
# 54694                                          NaN
# 54695                                          NaN
# 54696                                          NaN
# 54697                                          NaN
# 54698                                          NaN
# 54699                                          NaN
# 54700                                          NaN
# 54702                                          NaN
# 54703                                          NaN
# 54704                                          NaN
# 54705                                          NaN
# 54706                                          NaN
# 54707                                          NaN
# 54708                                          NaN
# 54709                                          NaN
# 54710                                          NaN
# 54711                                          NaN
# 54712                                          NaN
# 54713                                          NaN
# 54722                                          NaN
# 54800                                          NaN
# 54896  http://www.pumbagamereserve.co.za/amenities
# 54898                                          NaN
# 54919                                          NaN
# 54946                                          NaN
# 55021                                          NaN
# 55282                   http://www.sealandgov.org/
#
#                                           wikipedia_link  \
# 0                                                    NaN
# 9                                                    NaN
# 12                                                   NaN
# 15                                                   NaN
# 16                                                   NaN
# 19                                                   NaN
# 21                                                   NaN
# 25                                                   NaN
# 26                                                   NaN
# 29                                                   NaN
# 35                                                   NaN
# 39                                                   NaN
# 41                                                   NaN
# 42                                                   NaN
# 48                                                   NaN
# 49                                                   NaN
# 61                                                   NaN
# 64                                                   NaN
# 66                                                   NaN
# 67                                                   NaN
# 69                                                   NaN
# 71                                                   NaN
# 72                                                   NaN
# 73                                                   NaN
# 75                                                   NaN
# 77                                                   NaN
# 82                                                   NaN
# 83                                                   NaN
# 88                                                   NaN
# 92                                                   NaN
# ...                                                  ...
# 54691                                                NaN
# 54692                                                NaN
# 54693                                                NaN
# 54694                                                NaN
# 54695                                                NaN
# 54696                                                NaN
# 54697                                                NaN
# 54698                                                NaN
# 54699                                                NaN
# 54700                                                NaN
# 54702                                                NaN
# 54703                                                NaN
# 54704                                                NaN
# 54705                                                NaN
# 54706                                                NaN
# 54707                                                NaN
# 54708                                                NaN
# 54709                                                NaN
# 54710                                                NaN
# 54711                                                NaN
# 54712                                                NaN
# 54713                                                NaN
# 54722                                                NaN
# 54800                                                NaN
# 54896                                                NaN
# 54898                                                NaN
# 54919                                                NaN
# 54946                                                NaN
# 55021                                                NaN
# 55282  http://en.wikipedia.org/wiki/Principality_of_S...
#
#                          keywords
# 0                             NaN
# 9                             NaN
# 12                            NaN
# 15                            NaN
# 16                            NaN
# 19                            NaN
# 21                            NaN
# 25                            NaN
# 26                            NaN
# 29                            NaN
# 35                            NaN
# 39                            NaN
# 41                            NaN
# 42                            NaN
# 48                            NaN
# 49                            NaN
# 61                            NaN
# 64                            NaN
# 66                            NaN
# 67                            NaN
# 69                            NaN
# 71                            NaN
# 72                            NaN
# 73                            NaN
# 75     Florida Hospital-Altamonte
# 77                            NaN
# 82                            NaN
# 83                            NaN
# 88                            NaN
# 92                            NaN
# ...                           ...
# 54691                         NaN
# 54692                         NaN
# 54693                         NaN
# 54694                         NaN
# 54695                         NaN
# 54696                         NaN
# 54697                         NaN
# 54698                         NaN
# 54699                         NaN
# 54700                         NaN
# 54702                         NaN
# 54703                         NaN
# 54704                         NaN
# 54705                         NaN
# 54706                         NaN
# 54707                         NaN
# 54708                         NaN
# 54709                         NaN
# 54710                         NaN
# 54711                         NaN
# 54712                         NaN
# 54713                         NaN
# 54722                         NaN
# 54800                         NaN
# 54896                         NaN
# 54898                         NaN
# 54919                         NaN
# 54946                         NaN
# 55021                         NaN
# 55282        Roughs Tower Helipad
#
# [11340 rows x 18 columns]

# %%
# select * from airports where type not in ('heliport', 'balloonport') 
airports[~airports.type.isin(['heliport', 'balloonport'])]
# Out:
#            id    ident            type  \
# 1      323361     00AA   small_airport
# 2        6524     00AK   small_airport
# 3        6525     00AL   small_airport
# 4        6526     00AR          closed
# 5      322127     00AS   small_airport
# 6        6527     00AZ   small_airport
# 7        6528     00CA   small_airport
# 8      324424     00CL   small_airport
# 10       6529     00CO          closed
# 11       6531     00FA   small_airport
# 13       6533     00FL   small_airport
# 14       6534     00GA   small_airport
# 17       6537     00ID   small_airport
# 18     322581     00IG   small_airport
# 20       6539     00IL   small_airport
# 22       6541     00IS   small_airport
# 23       6542     00KS   small_airport
# 24       6543     00KY   small_airport
# 27       6545     00LS   small_airport
# 28       6546     00MD   small_airport
# 30       6548     00MN   small_airport
# 31       6549     00MO   small_airport
# 32       6550     00MT          closed
# 33       6551      00N   small_airport
# 34       6552     00NC   small_airport
# 36     321919     00NK   seaplane_base
# 37       6554     00NY   small_airport
# 38       6555     00OH   small_airport
# 40     328503     00OK   small_airport
# 43      45773     00PN   small_airport
# ...       ...      ...             ...
# 55254   32725     ZWYN   small_airport
# 55255   30646     ZYAS  medium_airport
# 55256   27237     ZYCC  medium_airport
# 55257  300858     ZYCH  medium_airport
# 55258   30827     ZYCY  medium_airport
# 55259  327349     ZYDU  medium_airport
# 55260  324338     ZYFX   small_airport
# 55261  313994     ZYFY  medium_airport
# 55262   27238     ZYHB   large_airport
# 55263   31576     ZYHE  medium_airport
# 55264   31701     ZYJL   small_airport
# 55265   27239     ZYJM  medium_airport
# 55266  327450     ZYJS  medium_airport
# 55267  313337     ZYJX  medium_airport
# 55268   31706     ZYJZ  medium_airport
# 55269  307012     ZYLD  medium_airport
# 55270  300516     ZYLS  medium_airport
# 55271   27240     ZYMD  medium_airport
# 55272  301193     ZYMH  medium_airport
# 55273   27241     ZYQQ  medium_airport
# 55274  327451     ZYSQ  medium_airport
# 55275  307017     ZYTH   small_airport
# 55276   27242     ZYTL   large_airport
# 55277  307013     ZYTN  medium_airport
# 55278   27243     ZYTX   large_airport
# 55279   27244     ZYYJ  medium_airport
# 55280  317861     ZYYK  medium_airport
# 55281   32753     ZYYY  medium_airport
# 55283  307326  ZZ-0002   small_airport
# 55284  313629     ZZZZ   small_airport
#
#                                            name  latitude_deg  longitude_deg  \
# 1                          Aero B Ranch Airport     38.704022    -101.473911
# 2                                  Lowell Field     59.949200    -151.695999
# 3                                  Epps Airpark     34.864799     -86.770302
# 4            Newport Hospital & Clinic Heliport     35.608700     -91.254898
# 5                                Fulton Airport     34.942803     -97.818019
# 6                                Cordes Airport     34.305599    -112.165001
# 7                       Goldstone /Gts/ Airport     35.350498    -116.888000
# 8                           Williams Ag Airport     39.427188    -121.763427
# 10                                   Cass Field     40.622202    -104.344002
# 11                          Grass Patch Airport     28.645500     -82.219002
# 13                            River Oak Airport     27.230900     -80.969200
# 14                             Lt World Airport     33.767502     -84.068298
# 17                         Delta Shores Airport     48.145302    -116.213997
# 18                                Goltl Airport     39.724028    -101.395994
# 20                               Hammer Airport     41.978401     -89.560402
# 22            Hayenga's Cant Find Farms Airport     40.025600     -89.122902
# 23                          Hayden Farm Airport     38.727798     -94.930496
# 24                        Robbins Roost Airport     37.409401     -84.619698
# 27                              Lejeune Airport     30.136299     -92.429398
# 28                                 Slater Field     38.757099     -75.753799
# 30                Battle Lake Municipal Airport     46.299999     -95.700302
# 31                Cooper Flying Service Airport     37.202801     -94.412399
# 32                          Sands Ranch Airport     48.537498    -109.705002
# 33                                Bucks Airport     39.473202     -75.185204
# 34                        North Raleigh Airport     36.085201     -78.371399
# 36                    Cliche Cove Seaplane Base     44.811861     -73.369806
# 37                               Weiss Airfield     42.900101     -77.499702
# 38                               Exit 3 Airport     41.590900     -84.142197
# 40                     Gull Bay Landing Airport     36.198598     -96.217693
# 43                                Ferrell Field     41.299500     -80.211111
# ...                                         ...           ...            ...
# 55254                            Yining Airport     43.955799      81.330299
# 55255                           Anshan Air Base     41.105301     122.853996
# 55256                           Longjia Airport     43.996201     125.684998
# 55257                          Changhai Airport     39.266667     122.666944
# 55258                          Chaoyang Airport     41.538101     120.434998
# 55259                  Wudalianchi Dedu Airport     48.445000     126.133000
# 55260                             Fuxin Airport     42.069014     121.718122
# 55261                             Dongji Aiport     48.199494     134.366447
# 55262                           Taiping Airport     45.623402     126.250000
# 55263                             Heihe Airport     50.171621     127.308884
# 55264                             Jilin Airport     44.002201     126.396004
# 55265                           Jiamusi Airport     46.843399     130.464996
# 55266                      Jiansanjiang Airport     47.110000     132.660278
# 55267                    Jixi Xingkaihu Airport     45.293000     131.193000
# 55268                           Jinzhou Airport     41.101398     121.061996
# 55269                             Lindu Airport     47.752056     129.019125
# 55270                      Yushu Batang Airport     32.836389      97.036389
# 55271  Mudanjiang Hailang International Airport     44.524101     129.569000
# 55272                           Gu-Lian Airport     52.912778     122.430000
# 55273                  Qiqihar Sanjiazi Airport     47.239601     123.917999
# 55274                 Songyuan Chaganhu Airport     44.938114     124.550178
# 55275                              Tahe Airport     52.224444     124.720222
# 55276                        Zhoushuizi Airport     38.965698     121.539001
# 55277                 Tonghua Sanyuanpu Airport     42.253889     125.703333
# 55278                           Taoxian Airport     41.639801     123.483002
# 55279               Yanji Chaoyangchuan Airport     42.882801     129.451004
# 55280                     Yingkou Lanqi Airport     40.542524     122.358600
# 55281                   Shenyang Dongta Airport     41.784401     123.496002
# 55283                 Glorioso Islands Airstrip    -11.584278      47.296389
# 55284                    Satsuma Iōjima Airport     30.784722     130.270556
#
#        elevation_ft continent iso_country iso_region  \
# 1            3435.0       NaN          US      US-KS
# 2             450.0       NaN          US      US-AK
# 3             820.0       NaN          US      US-AL
# 4             237.0       NaN          US      US-AR
# 5            1100.0       NaN          US      US-OK
# 6            3810.0       NaN          US      US-AZ
# 7            3038.0       NaN          US      US-CA
# 8              87.0       NaN          US      US-CA
# 10           4830.0       NaN          US      US-CO
# 11             53.0       NaN          US      US-FL
# 13             35.0       NaN          US      US-FL
# 14            700.0       NaN          US      US-GA
# 17           2064.0       NaN          US      US-ID
# 18           3359.0       NaN          US      US-KS
# 20            840.0       NaN          US      US-IL
# 22            820.0       NaN          US      US-IL
# 23           1100.0       NaN          US      US-KS
# 24           1265.0       NaN          US      US-KY
# 27             12.0       NaN          US      US-LA
# 28             45.0       NaN          US      US-MD
# 30           1365.0       NaN          US      US-MN
# 31            970.0       NaN          US      US-MO
# 32           2600.0       NaN          US      US-MT
# 33            105.0       NaN          US      US-NJ
# 34            348.0       NaN          US      US-NC
# 36             96.0       NaN          US      US-NY
# 37           1000.0       NaN          US      US-NY
# 38            785.0       NaN          US      US-OH
# 40            960.0       NaN          US      US-OK
# 43           1301.0       NaN          US      US-PA
# ...             ...       ...         ...        ...
# 55254           NaN        AS          CN      CN-65
# 55255           NaN        AS          CN      CN-21
# 55256         706.0        AS          CN      CN-22
# 55257          80.0        AS          CN      CN-21
# 55258         568.0        AS          CN      CN-21
# 55259         984.0        AS          CN      CN-23
# 55260         548.0        AS          CN      CN-21
# 55261           NaN        AS          CN      CN-23
# 55262         457.0        AS          CN      CN-23
# 55263        8530.0        AS          CN      CN-23
# 55264           NaN        AS          CN      CN-22
# 55265         262.0        AS          CN      CN-23
# 55266           NaN        AS          CN      CN-23
# 55267         760.0        AS          CN      CN-23
# 55268           NaN        AS          CN      CN-21
# 55269         791.0        AS          CN      CN-23
# 55270       12816.0        AS          CN      CN-63
# 55271         883.0        AS          CN      CN-23
# 55272        1836.0        AS          CN      CN-23
# 55273         477.0        AS          CN      CN-23
# 55274         459.0        AS          CN      CN-22
# 55275        1240.0        AS          CN      CN-23
# 55276         107.0        AS          CN      CN-21
# 55277        1200.0        AS          CN      CN-22
# 55278         198.0        AS          CN      CN-21
# 55279         624.0        AS          CN      CN-22
# 55280           0.0        AS          CN      CN-21
# 55281           NaN        AS          CN      CN-21
# 55283          11.0        AF          TF     TF-U-A
# 55284         338.0        AS          JP      JP-46
#
#                                municipality scheduled_service gps_code  \
# 1                                     Leoti                no     00AA
# 2                              Anchor Point                no     00AK
# 3                                   Harvest                no     00AL
# 4                                   Newport                no      NaN
# 5                                      Alex                no     00AS
# 6                                    Cordes                no     00AZ
# 7                                   Barstow                no     00CA
# 8                                     Biggs                no     00CL
# 10                               Briggsdale                no      NaN
# 11                                 Bushnell                no     00FA
# 13                               Okeechobee                no     00FL
# 14                                 Lithonia                no     00GA
# 17                               Clark Fork                no     00ID
# 18                                 McDonald                no     00IG
# 20                                     Polo                no     00IL
# 22                                    Kings                no     00IS
# 23                                  Gardner                no     00KS
# 24                                 Stanford                no     00KY
# 27                                Esterwood                no     00LS
# 28                             Federalsburg                no     00MD
# 30                              Battle Lake                no     00MN
# 31                                     Alba                no     00MO
# 32                                    Havre                no      NaN
# 33                                Bridgeton                no      00N
# 34                                Louisburg                no     00NC
# 36                              Beekmantown                no     00NK
# 37                          West Bloomfield                no     00NY
# 38                                  Wauseon                no     00OH
# 40                              Sandsprings                no     00OK
# 43                                   Mercer                no     00PN
# ...                                     ...               ...      ...
# 55254                                Yining               yes     ZWYN
# 55255                                Anshan               yes     ZYAS
# 55256                             Changchun               yes     ZYCC
# 55257                              Changhai                no     ZYCH
# 55258                              Chaoyang               yes     ZYCY
# 55259                           Wudalianchi               yes     ZYDU
# 55260                                 Fuxin                no     ZYFX
# 55261                                Fuyuan               yes     ZYFY
# 55262                                Harbin               yes     ZYHB
# 55263                                 Heihe               yes     ZYHE
# 55264                                 Jilin                no     ZYJL
# 55265                               Jiamusi               yes     ZYJM
# 55266                          Jiansanjiang               yes     ZYJS
# 55267                                  Jixi               yes     ZYJX
# 55268                               Jinzhou               yes     ZYJZ
# 55269                                Yichun               yes     ZYLD
# 55270                                 Yushu                no     ZYLS
# 55271                            Mudanjiang               yes     ZYMD
# 55272                                  Mohe               yes     ZYMH
# 55273                               Qiqihar               yes     ZYQQ
# 55274  Qian Gorlos Mongol Autonomous County               yes     ZYSQ
# 55275                                  Tahe                no     ZYTH
# 55276                                Dalian               yes     ZYTL
# 55277                               Tonghua               yes     ZYTN
# 55278                              Shenyang               yes     ZYTX
# 55279                                 Yanji               yes     ZYYJ
# 55280                               Yingkou               yes     ZYYK
# 55281                              Shenyang                no     ZYYY
# 55283                      Grande Glorieuse                no      NaN
# 55284                          Mishima-Mura                no     RJX7
#
#       iata_code local_code home_link  \
# 1           NaN       00AA       NaN
# 2           NaN       00AK       NaN
# 3           NaN       00AL       NaN
# 4           NaN        NaN       NaN
# 5           NaN       00AS       NaN
# 6           NaN       00AZ       NaN
# 7           NaN       00CA       NaN
# 8           NaN       00CL       NaN
# 10          NaN        NaN       NaN
# 11          NaN       00FA       NaN
# 13          NaN       00FL       NaN
# 14          NaN       00GA       NaN
# 17          NaN       00ID       NaN
# 18          NaN       00IG       NaN
# 20          NaN       00IL       NaN
# 22          NaN       00IS       NaN
# 23          NaN       00KS       NaN
# 24          NaN       00KY       NaN
# 27          NaN       00LS       NaN
# 28          NaN       00MD       NaN
# 30          NaN       00MN       NaN
# 31          NaN       00MO       NaN
# 32          NaN        NaN       NaN
# 33          NaN        00N       NaN
# 34          NaN       00NC       NaN
# 36          NaN       00NK       NaN
# 37          NaN       00NY       NaN
# 38          NaN       00OH       NaN
# 40          NaN       00OK       NaN
# 43          NaN       00PN       NaN
# ...         ...        ...       ...
# 55254       YIN        NaN       NaN
# 55255       AOG        NaN       NaN
# 55256       CGQ        NaN       NaN
# 55257       CNI        NaN       NaN
# 55258       CHG        NaN       NaN
# 55259       DTU        NaN       NaN
# 55260       NaN        NaN       NaN
# 55261       FYJ        NaN       NaN
# 55262       HRB        NaN       NaN
# 55263       HEK        NaN       NaN
# 55264       JIL        NaN       NaN
# 55265       JMU        NaN       NaN
# 55266       JSJ        NaN       NaN
# 55267       JXA        NaN       NaN
# 55268       JNZ        NaN       NaN
# 55269       LDS        NaN       NaN
# 55270       YUS        NaN       NaN
# 55271       MDG        NaN       NaN
# 55272       OHE        NaN       NaN
# 55273       NDG        NaN       NaN
# 55274       YSQ        NaN       NaN
# 55275       NaN        NaN       NaN
# 55276       DLC        NaN       NaN
# 55277       TNH        NaN       NaN
# 55278       SHE        NaN       NaN
# 55279       YNJ        NaN       NaN
# 55280       YKH        NaN       NaN
# 55281       NaN        NaN       NaN
# 55283       NaN        NaN       NaN
# 55284       NaN        NaN       NaN
#
#                                           wikipedia_link  \
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# 5                                                    NaN
# 6                                                    NaN
# 7                                                    NaN
# 8                                                    NaN
# 10                                                   NaN
# 11                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 17                                                   NaN
# 18                                                   NaN
# 20                                                   NaN
# 22                                                   NaN
# 23                                                   NaN
# 24                                                   NaN
# 27                                                   NaN
# 28                                                   NaN
# 30                                                   NaN
# 31                                                   NaN
# 32                                                   NaN
# 33                                                   NaN
# 34                                                   NaN
# 36                                                   NaN
# 37                                                   NaN
# 38                                                   NaN
# 40                                                   NaN
# 43                                                   NaN
# ...                                                  ...
# 55254       https://en.wikipedia.org/wiki/Yining_Airport
# 55255  https://en.wikipedia.org/wiki/Anshan_Teng%27ao...
# 55256  http://en.wikipedia.org/wiki/Changchun_Longjia...
# 55257      http://en.wikipedia.org/wiki/Changhai_Airport
# 55258     https://en.wikipedia.org/wiki/Chaoyang_Airport
# 55259  https://en.wikipedia.org/wiki/Wudalianchi_Dedu...
# 55260                                                NaN
# 55261  https://en.wikipedia.org/wiki/Fuyuan_Dongji_Ai...
# 55262  http://en.wikipedia.org/wiki/Harbin_Taiping_In...
# 55263         http://en.wikipedia.org/wiki/Heihe_Airport
# 55264  https://en.wikipedia.org/wiki/Jilin_Ertaizi_Ai...
# 55265       http://en.wikipedia.org/wiki/Jiamusi_Airport
# 55266  https://en.wikipedia.org/wiki/Jiansanjiang_Air...
# 55267  http://en.wikipedia.org/wiki/Jixi_Xingkaihu_Ai...
# 55268       http://en.wikipedia.org/wiki/Jinzhou_Airport
# 55269  http://en.wikipedia.org/wiki/Yichun_Lindu_Airport
# 55270  http://en.wikipedia.org/wiki/Yushu_Batang_Airport
# 55271    http://en.wikipedia.org/wiki/Mudanjiang_Airport
# 55272   http://en.wikipedia.org/wiki/Mohe_Gulian_Airport
# 55273       http://en.wikipedia.org/wiki/Qiqihar_Airport
# 55274  https://en.wikipedia.org/wiki/Songyuan_Chaganh...
# 55275                                                NaN
# 55276  http://en.wikipedia.org/wiki/Dalian_Zhoushuizi...
# 55277  http://en.wikipedia.org/wiki/Tonghua_Sanyuanpu...
# 55278  http://en.wikipedia.org/wiki/Shenyang_Taoxian_...
# 55279  http://en.wikipedia.org/wiki/Yanji_Chaoyangchu...
# 55280  https://en.wikipedia.org/wiki/Yingkou_Lanqi_Ai...
# 55281                                                NaN
# 55283                                                NaN
# 55284  http://wikimapia.org/6705190/Satsuma-Iwo-jima-...
#
#                     keywords
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                       00AR
# 5                        NaN
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 10                      00CO
# 11                       NaN
# 13                       NaN
# 14                       NaN
# 17                       NaN
# 18                       NaN
# 20                       NaN
# 22                       NaN
# 23                       NaN
# 24                       NaN
# 27                       NaN
# 28                       NaN
# 30                       NaN
# 31                       5K8
# 32                      00MT
# 33                       NaN
# 34                       NaN
# 36                       NaN
# 37                       NaN
# 38                       NaN
# 40                       NaN
# 43                       NaN
# ...                      ...
# 55254                    NaN
# 55255                    NaN
# 55256                    NaN
# 55257                    NaN
# 55258                    NaN
# 55259                    NaN
# 55260                    NaN
# 55261                    NaN
# 55262                    NaN
# 55263                    NaN
# 55264                    NaN
# 55265                    NaN
# 55266                    NaN
# 55267                    NaN
# 55268    Xiaolingzi Air Base
# 55269     Yichun Shi Airport
# 55270                    NaN
# 55271             Mudanjiang
# 55272                    NaN
# 55273                    NaN
# 55274                    NaN
# 55275                    NaN
# 55276        Dalian Air Base
# 55277  Tonghua Liuhe Airport
# 55278                    NaN
# 55279                    NaN
# 55280                    NaN
# 55281                    NaN
# 55283                    NaN
# 55284   SATSUMA,IWOJIMA,RJX7
#
# [43945 rows x 18 columns]

# %%
# select iso_country, type, count(&ast;) from airports group by iso_country, type order by iso_country, type              
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           heliport            2
# AE           closed              5
#              heliport           21
#              large_airport       4
#              medium_airport      9
#              seaplane_base       3
#              small_airport      16
# AF           closed              2
#              heliport            3
#              medium_airport      8
#              small_airport      51
# AG           medium_airport      1
#              small_airport       2
# AI           medium_airport      1
# AL           balloonport         1
#              closed              6
#              heliport            1
#              large_airport       1
#              medium_airport      4
#              small_airport       6
# AM           closed              4
#              large_airport       2
#              medium_airport      3
#              small_airport       5
# AO           closed             10
#              large_airport       1
#              medium_airport     20
#              small_airport      73
# AQ           closed              2
#              medium_airport      4
#                               ...
# VN           heliport            5
#              large_airport       3
#              medium_airport     18
#              small_airport      16
# VU           medium_airport      4
#              small_airport      28
# WF           medium_airport      2
# WS           medium_airport      1
#              small_airport       3
# XK           closed              2
#              heliport            2
#              large_airport       1
#              medium_airport      1
# YE           medium_airport     11
#              small_airport      14
# YT           medium_airport      1
# ZA           closed             12
#              heliport            6
#              large_airport       9
#              medium_airport     57
#              small_airport     413
# ZM           closed              1
#              large_airport       1
#              medium_airport      7
#              small_airport      94
# ZW           closed              3
#              large_airport       2
#              medium_airport      8
#              small_airport     127
# ZZ           closed              7
# Length: 852, dtype: int64

# %%
# select iso_country, type, count(&ast;) from airports group by iso_country, type order by iso_country, count(&ast;) desc 
airports.groupby(['iso_country', 'type']).size().to_frame('size').reset_index().sort_values(['iso_country', 'size'], ascending=[True, False])
# Out:
#     iso_country            type  size
# 0            AD        heliport     2
# 2            AE        heliport    21
# 6            AE   small_airport    16
# 4            AE  medium_airport     9
# 1            AE          closed     5
# 3            AE   large_airport     4
# 5            AE   seaplane_base     3
# 10           AF   small_airport    51
# 9            AF  medium_airport     8
# 8            AF        heliport     3
# 7            AF          closed     2
# 12           AG   small_airport     2
# 11           AG  medium_airport     1
# 13           AI  medium_airport     1
# 15           AL          closed     6
# 19           AL   small_airport     6
# 18           AL  medium_airport     4
# 14           AL     balloonport     1
# 16           AL        heliport     1
# 17           AL   large_airport     1
# 23           AM   small_airport     5
# 20           AM          closed     4
# 22           AM  medium_airport     3
# 21           AM   large_airport     2
# 27           AO   small_airport    73
# 26           AO  medium_airport    20
# 24           AO          closed    10
# 25           AO   large_airport     1
# 30           AQ   small_airport    21
# 29           AQ  medium_airport     4
# ..          ...             ...   ...
# 825          VN   small_airport    16
# 821          VN          closed     8
# 822          VN        heliport     5
# 823          VN   large_airport     3
# 827          VU   small_airport    28
# 826          VU  medium_airport     4
# 828          WF  medium_airport     2
# 830          WS   small_airport     3
# 829          WS  medium_airport     1
# 831          XK          closed     2
# 832          XK        heliport     2
# 833          XK   large_airport     1
# 834          XK  medium_airport     1
# 836          YE   small_airport    14
# 835          YE  medium_airport    11
# 837          YT  medium_airport     1
# 842          ZA   small_airport   413
# 841          ZA  medium_airport    57
# 838          ZA          closed    12
# 840          ZA   large_airport     9
# 839          ZA        heliport     6
# 846          ZM   small_airport    94
# 845          ZM  medium_airport     7
# 843          ZM          closed     1
# 844          ZM   large_airport     1
# 850          ZW   small_airport   127
# 849          ZW  medium_airport     8
# 847          ZW          closed     3
# 848          ZW   large_airport     2
# 851          ZZ          closed     7
#
# [852 rows x 3 columns]

# %%
# select iso_country, type, count(&ast;) from airports group by iso_country, type order by iso_country, type              
airports.groupby(['iso_country', 'type']).size()
# Out:
# iso_country  type
# AD           heliport            2
# AE           closed              5
#              heliport           21
#              large_airport       4
#              medium_airport      9
#              seaplane_base       3
#              small_airport      16
# AF           closed              2
#              heliport            3
#              medium_airport      8
#              small_airport      51
# AG           medium_airport      1
#              small_airport       2
# AI           medium_airport      1
# AL           balloonport         1
#              closed              6
#              heliport            1
#              large_airport       1
#              medium_airport      4
#              small_airport       6
# AM           closed              4
#              large_airport       2
#              medium_airport      3
#              small_airport       5
# AO           closed             10
#              large_airport       1
#              medium_airport     20
#              small_airport      73
# AQ           closed              2
#              medium_airport      4
#                               ...
# VN           heliport            5
#              large_airport       3
#              medium_airport     18
#              small_airport      16
# VU           medium_airport      4
#              small_airport      28
# WF           medium_airport      2
# WS           medium_airport      1
#              small_airport       3
# XK           closed              2
#              heliport            2
#              large_airport       1
#              medium_airport      1
# YE           medium_airport     11
#              small_airport      14
# YT           medium_airport      1
# ZA           closed             12
#              heliport            6
#              large_airport       9
#              medium_airport     57
#              small_airport     413
# ZM           closed              1
#              large_airport       1
#              medium_airport      7
#              small_airport      94
# ZW           closed              3
#              large_airport       2
#              medium_airport      8
#              small_airport     127
# ZZ           closed              7
# Length: 852, dtype: int64

# %%
# select iso_country, type, count(&ast;) from airports group by iso_country, type order by iso_country, count(&ast;) desc
airports.groupby(['iso_country', 'type']).size().to_frame('size').reset_index().sort_values(['iso_country', 'size'], ascending=[True, False])
# Out:
#     iso_country            type  size
# 0            AD        heliport     2
# 2            AE        heliport    21
# 6            AE   small_airport    16
# 4            AE  medium_airport     9
# 1            AE          closed     5
# 3            AE   large_airport     4
# 5            AE   seaplane_base     3
# 10           AF   small_airport    51
# 9            AF  medium_airport     8
# 8            AF        heliport     3
# 7            AF          closed     2
# 12           AG   small_airport     2
# 11           AG  medium_airport     1
# 13           AI  medium_airport     1
# 15           AL          closed     6
# 19           AL   small_airport     6
# 18           AL  medium_airport     4
# 14           AL     balloonport     1
# 16           AL        heliport     1
# 17           AL   large_airport     1
# 23           AM   small_airport     5
# 20           AM          closed     4
# 22           AM  medium_airport     3
# 21           AM   large_airport     2
# 27           AO   small_airport    73
# 26           AO  medium_airport    20
# 24           AO          closed    10
# 25           AO   large_airport     1
# 30           AQ   small_airport    21
# 29           AQ  medium_airport     4
# ..          ...             ...   ...
# 825          VN   small_airport    16
# 821          VN          closed     8
# 822          VN        heliport     5
# 823          VN   large_airport     3
# 827          VU   small_airport    28
# 826          VU  medium_airport     4
# 828          WF  medium_airport     2
# 830          WS   small_airport     3
# 829          WS  medium_airport     1
# 831          XK          closed     2
# 832          XK        heliport     2
# 833          XK   large_airport     1
# 834          XK  medium_airport     1
# 836          YE   small_airport    14
# 835          YE  medium_airport    11
# 837          YT  medium_airport     1
# 842          ZA   small_airport   413
# 841          ZA  medium_airport    57
# 838          ZA          closed    12
# 840          ZA   large_airport     9
# 839          ZA        heliport     6
# 846          ZM   small_airport    94
# 845          ZM  medium_airport     7
# 843          ZM          closed     1
# 844          ZM   large_airport     1
# 850          ZW   small_airport   127
# 849          ZW  medium_airport     8
# 847          ZW          closed     3
# 848          ZW   large_airport     2
# 851          ZZ          closed     7
#
# [852 rows x 3 columns]

# %%
# select type, count(&ast;) from airports where iso_country = 'US' group by type having count(&ast;) > 1000 order by count(&ast;) desc 
airports[airports.iso_country == 'US'].groupby('type').filter(lambda g: len(g) > 1000).groupby('type').size().sort_values(ascending=False)
# Out:
# type
# small_airport    13714
# heliport          6258
# closed            1369
# dtype: int64

# %%
by_country = airports.groupby(["iso_country"]).count()["id"].reset_index()
by_country = by_country.rename(columns={"id":"airport_count"})
by_country
# Out:
#     iso_country  airport_count
# 0            AD              2
# 1            AE             58
# 2            AF             64
# 3            AG              3
# 4            AI              1
# 5            AL             19
# 6            AM             14
# 7            AO            104
# 8            AQ             27
# 9            AR            848
# 10           AS              4
# 11           AT            146
# 12           AU           1966
# 13           AW              1
# 14           AZ             35
# 15           BA             15
# 16           BB              6
# 17           BD             16
# 18           BE            146
# 19           BF             51
# 20           BG            134
# 21           BH              4
# 22           BI              7
# 23           BJ             10
# 24           BL              1
# 25           BM              3
# 26           BN              2
# 27           BO            197
# 28           BQ              3
# 29           BR           4356
# ..          ...            ...
# 213          TM             21
# 214          TN             15
# 215          TO              6
# 216          TR            124
# 217          TT              3
# 218          TV              3
# 219          TW             65
# 220          TZ            207
# 221          UA            191
# 222          UG             39
# 223          UM              7
# 224          US          22786
# 225          UY             54
# 226          UZ            176
# 227          VA              1
# 228          VC              6
# 229          VE            592
# 230          VG              3
# 231          VI              9
# 232          VN             50
# 233          VU             32
# 234          WF              2
# 235          WS              4
# 236          XK              6
# 237          YE             25
# 238          YT              1
# 239          ZA            497
# 240          ZM            103
# 241          ZW            140
# 242          ZZ              7
#
# [243 rows x 2 columns]

# %%
# select iso_country from by_country order by size desc limit 10 
top10 = by_country.nlargest(10, columns='airport_count')
top10
# Out:
#     iso_country  airport_count
# 224          US          22786
# 29           BR           4356
# 35           CA           2786
# 12           AU           1966
# 117          KR           1376
# 152          MX           1220
# 184          RU           1068
# 54           DE            957
# 74           GB            926
# 72           FR            860

# %%
# select iso_country from by_country order by size desc limit 10 offset 10 
by_country.nlargest(20, columns='airport_count').tail(10)
# Out:
#     iso_country  airport_count
# 9            AR            848
# 46           CO            706
# 105          IT            675
# 170          PG            594
# 229          VE            592
# 239          ZA            497
# 43           CL            474
# 96           ID            471
# 65           ES            417
# 45           CN            405

# %%
#  select max(length_ft), min(length_ft), mean(length_ft), median(length_ft) from runways 
runways.agg({'length_ft': ['min', 'max', 'mean', 'median']})
# Out:
#             length_ft
# min          0.000000
# max     120000.000000
# mean      3265.626545
# median    2750.000000

# %%
# select airport_ident, type, description, frequency_mhz from airport_freq join airports on airport_freq.airport_ref = airports.id where airports.ident = 'KLAX'
airport_freq.merge(airports[airports.ident == 'KLAX'][['id']], left_on='airport_ref', right_on='id', how='inner')[['airport_ident', 'type', 'description', 'frequency_mhz']]
# Out:
#    airport_ident  type description  frequency_mhz
# 0           KLAX   APP   SOCAL APP          36.07
# 1           KLAX   APP   SOCAL APP         124.30
# 2           KLAX  ATIS        ATIS         133.80
# 3           KLAX   CLD    CLNC DEL         121.40
# 4           KLAX   DEP   SOCAL DEP         124.30
# 5           KLAX   GND         GND         121.65
# 6           KLAX  MISC          CG          34.50
# 7           KLAX  MISC          CG         898.40
# 8           KLAX   OPS          AF          37.22
# 9           KLAX   TWR         TWR         119.80
# 10          KLAX  UNIC      UNICOM         122.95

# %%
# select name, municipality from airports where ident = 'KLAX' union all select name, municipality from airports where ident = 'KLGB' 
pd.concat([airports[airports.ident == 'KLAX'][['name', 'municipality']], airports[airports.ident == 'KLGB'][['name', 'municipality']]])
# Out:
#                                        name municipality
# 27881     Los Angeles International Airport  Los Angeles
# 27906  Long Beach /Daugherty Field/ Airport   Long Beach

# %%
# create table heroes (id integer, name text);       
df1 = pd.DataFrame({'id': [1, 2], 'name': ['Harry Potter', 'Ron Weasley']})
df1
# Out:
#    id          name
# 0   1  Harry Potter
# 1   2   Ron Weasley

# %%
# insert into heroes values (1, 'Harry Potter');     
df2 = pd.DataFrame({'id': [3], 'name': ['Hermione Granger']}) 
df2
# Out:
#    id              name
# 0   3  Hermione Granger

# %%
# insert into heroes values (2, 'Ron Weasley');                                                                            |
# insert into heroes values (3, 'Hermione Granger');
pd.concat([df1, df2]).reset_index(drop=True)
# Out:
#    id              name
# 0   1      Harry Potter
# 1   2       Ron Weasley
# 2   3  Hermione Granger

# %%
# update airports set home_link = 'http://www.lawa.org/welcomelax.aspx' where ident == 'KLAX' 
airports.loc[airports['ident'] == 'KLAX', 'home_link'] = 'http://www.lawa.org/welcomelax.aspx'

# %%
# delete from lax_freq where type = 'MISC' 
lax_freq = lax_freq[lax_freq.type != 'MISC']
lax_freq.drop(lax_freq[lax_freq.type == 'MISC'].index)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-e5d12ac4f3cd> in <module>
#       1 # delete from lax_freq where type = 'MISC'
# ----> 2 lax_freq = lax_freq[lax_freq.type != 'MISC']
#
# NameError: name 'lax_freq' is not defined

# %%
df.reset_index(drop=True, inplace=True)

# %%
df['url'] = 'http://google.com'

# %%
df['total_cost'] = df['price'] * df['quantity']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python\python35\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-3387ab16fabc> in <module>
# ----> 1 df['total_cost'] = df['price'] * df['quantity']
#
# c:\python\python35\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# c:\python\python35\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'

# %%
df.to_csv(...)  # csv file
df.to_hdf(...)  # HDF5 file
df.to_pickle(...)  # serialized object
df.to_sql(...)  # to SQL database
df.to_excel(...)  # to Excel sheet
df.to_json(...)  # to JSON string
df.to_html(...)  # render as HTML table
df.to_feather(...)  # binary feather-format
df.to_latex(...)  # tabular environment table
df.to_stata(...)  # Stata binary data files
df.to_msgpack(...)	# msgpack (serialize) object
df.to_gbq(...)  # to a Google BigQuery table.
df.to_string(...)  # console-friendly tabular output.
df.to_clipboard(...) # clipboard that can be pasted into Excel

# %%
top10.plot(
    x='iso_country', 
    y='airport_count',
    kind='barh',
    figsize=(10, 7),
    title='Top 10 countries with most airports')
